# %%
from datasets import load_dataset
import pandas as pd
import os

os.makedirs("../data/raw", exist_ok=True)

# CSV list
csv_files = [
    "POS_CASH_balance.csv",
    "application_tr.csv",
    "application_ts.csv",
    "bureau.csv",
    "bureau_balance.csv",
    "credit_card_balance.csv",
    "installments_payments.csv",
    "previous_application.csv",
    "sample_submission.csv",
    "HomeCredit_columns_description.csv"
]

# User and repo in HuggingFace
USER = "jamirc"
REPO = "home_credit_default_risk"

for csv_name in csv_files:
    print(f"Downloading {csv_name} from HuggingFace...")

    url = f"https://huggingface.co/datasets/{USER}/{REPO}/resolve/main/{csv_name}"

    ds = load_dataset("csv", data_files=url)
    df = ds["train"].to_pandas()

    output_path = f"../data/raw/{csv_name}"
    df.to_csv(output_path, index=False)

    print(f"{csv_name} saved: {len(df):,} rows, {len(df.columns)} columns")
    print("=" * 40)
# Out:
# Downloading POS_CASH_balance.csv from HuggingFace...
# POS_CASH_balance.csv saved: 10,001,358 rows, 8 columns
# ========================================
# Downloading application_tr.csv from HuggingFace...
# application_tr.csv saved: 307,511 rows, 122 columns
# ========================================
# Downloading application_ts.csv from HuggingFace...
# application_ts.csv saved: 48,744 rows, 121 columns
# ========================================
# Downloading bureau.csv from HuggingFace...
# bureau.csv saved: 1,716,428 rows, 17 columns
# ========================================
# Downloading bureau_balance.csv from HuggingFace...
# bureau_balance.csv saved: 27,299,925 rows, 3 columns
# ========================================
# Downloading credit_card_balance.csv from HuggingFace...
# credit_card_balance.csv saved: 3,840,312 rows, 23 columns
# ========================================
# Downloading installments_payments.csv from HuggingFace...
# installments_payments.csv saved: 13,605,401 rows, 8 columns
# ========================================
# Downloading previous_application.csv from HuggingFace...
# previous_application.csv:   0%|          | 0.00/406M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# previous_application.csv saved: 1,670,214 rows, 37 columns
# ========================================
# Downloading sample_submission.csv from HuggingFace...
# sample_submission.csv: 0.00B [00:00, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# sample_submission.csv saved: 48,744 rows, 2 columns
# ========================================
# Downloading HomeCredit_columns_description.csv from HuggingFace...
# HomeCredit_columns_description.csv: 0.00B [00:00, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# HomeCredit_columns_description.csv saved: 219 rows, 5 columns
# ========================================
